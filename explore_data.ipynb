# %%
import tensorflow as tf
import json
from PIL import Image
from IPython.display import display
# Out:
# 2025-04-11 17:22:40.836218: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-11 17:22:40.952375: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-11 17:22:40.952452: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-11 17:22:40.952517: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-11 17:22:40.973135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2025-04-11 17:22:43.179164: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
from android_env.proto.a11y import android_accessibility_forest_pb2
# Out:
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_forest.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_window_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_tree.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_node_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_action.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/android_accessibility_node_info_clickable_span.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cs/anaconda3/envs/appvlm_tf/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.0 is exactly one major version older than the runtime version 6.30.2 at android_env/proto/a11y/rect.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
dataset = tf.data.TFRecordDataset("./dataset/android_control/android_control-00000-of-00020",compression_type="GZIP")

# %%
for raw_record in dataset.take(1):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())

    # 提取字段
    features = example.features.feature

    goal = features["goal"].bytes_list.value[0].decode("utf-8")
    screenshots = features["screenshots"].bytes_list.value
    widths = features["screenshot_widths"].int64_list.value
    heights = features["screenshot_heights"].int64_list.value
    step_instructions = [s.decode("utf-8") for s in features["step_instructions"].bytes_list.value]
    actions = [json.loads(a.decode("utf-8")) for a in features["actions"].bytes_list.value]
    episode_id = features["episode_id"].int64_list.value[0]
    accessibility_bytes = example.features.feature["accessibility_trees"].bytes_list.value[0]

    # 打印基本信息
    print(f"1 episode_id:{episode_id}")
    print(f"2 Goal: {goal}")
    print(f"3 Total screenshots: {len(screenshots)}")
    print(f"4 Widths: {widths}")
    print(f"5 Heights: {heights}")
    print(f"6 Instructions: {step_instructions}")
    print(f"7 Actions:")
    for i, act in enumerate(actions):
        print(f"  Step {i+1}: {act}")
    print("=" * 100, "\n")

    forest = android_accessibility_forest_pb2.AndroidAccessibilityForest().FromString(example.features.feature['accessibility_trees'].bytes_list.value[0])
    print(forest)
# Out:
# 1 episode_id:0
# 2 Goal: Open the Zoho Meet app , view the scheduled meetings .
# 3 Total screenshots: 4
# 4 Widths: [1080, 1080, 1080, 1080]
# 5 Heights: [2400, 2400, 2400, 2400]
# 6 Instructions: ['Open the Zoho Meet app', 'Open the Zoho Meet app', 'Go to the Past section']
# 7 Actions:
#   Step 1: {'action_type': 'open_app', 'app_name': 'Zoho Meeting'}
#   Step 2: {'action_type': 'wait'}
#   Step 3: {'action_type': 'click', 'x': 540, 'y': 390}
# ====================================================================================================
#
# windows {
#   bounds_in_screen {
#     right: 1080
#     bottom: 136
#   }
#   id: 5
#   layer: 1
#   window_type: TYPE_SYSTEM
#   tree {
#     nodes {
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 1
#       child_ids: 2
#       child_ids: 3
#     }
#     nodes {
#       unique_id: 1
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_launch_animation_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 1
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 2
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 1
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 3
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 4
#       depth: 1
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 4
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 5
#       depth: 2
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 5
#       bounds_in_screen {
#         left: 145
#         right: 1027
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_contents"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 6
#       child_ids: 7
#       depth: 3
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 6
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 575
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 8
#       depth: 4
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 7
#       bounds_in_screen {
#         left: 575
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_end_side_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 10
#       depth: 4
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 8
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_content"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 9
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 10
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_end_side_content"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 11
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 9
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_except_heads_up"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 12
#       child_ids: 13
#       depth: 6
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 11
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/system_icons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 14
#       child_ids: 15
#       depth: 6
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 12
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 229
#         bottom: 136
#       }
#       class_name: "android.widget.TextView"
#       content_description: "8:37 AM"
#       package_name: "com.android.systemui"
#       text: "8:37"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/clock"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 13
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/notification_icon_area"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 16
#       depth: 7
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 14
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 986
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/statusIcons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 17
#       depth: 7
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 15
#       bounds_in_screen {
#         left: 986
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       content_description: "Battery charging, 100 percent."
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/battery"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 18
#       depth: 7
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 16
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/notificationIcons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 19
#       child_ids: 20
#       child_ids: 21
#       child_ids: 22
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 17
#       bounds_in_screen {
#         left: 924
#         top: 39
#         right: 970
#         bottom: 97
#       }
#       class_name: "android.widget.FrameLayout"
#       content_description: "Wifi two bars."
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_combo"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 23
#       depth: 8
#       drawing_order: 14
#     }
#     nodes {
#       unique_id: 18
#       bounds_in_screen {
#         left: 986
#         top: 51
#         right: 1006
#         bottom: 85
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 19
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 287
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Clock notification: Missed alarm"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 20
#       bounds_in_screen {
#         left: 287
#         top: 1
#         right: 345
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Gmail notification: 6 new messages"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 21
#       bounds_in_screen {
#         left: 345
#         top: 1
#         right: 403
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "System update notification: Android 13"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 22
#       bounds_in_screen {
#         left: 403
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Google notification: Today in New Delhi: Scattered thunderstorms"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 23
#       bounds_in_screen {
#         left: 931
#         top: 39
#         right: 970
#         bottom: 97
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_group"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 24
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 24
#       bounds_in_screen {
#         left: 931
#         top: 48
#         right: 970
#         bottom: 87
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_combo"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 25
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 25
#       bounds_in_screen {
#         left: 931
#         top: 48
#         right: 970
#         bottom: 87
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_signal"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 1
#     }
#   }
# }
# windows {
#   bounds_in_screen {
#     right: 1080
#     bottom: 2400
#   }
#   id: 1729
#   title: "Calendar"
#   window_type: TYPE_APPLICATION
#   is_active: true
#   is_focused: true
#   tree {
#     nodes {
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 1
#     }
#     nodes {
#       unique_id: 1
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 2
#       depth: 1
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 2
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 3
#       depth: 2
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 3
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_bar_root"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 4
#       depth: 3
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 4
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "android:id/content"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 5
#       depth: 4
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 5
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "androidx.drawerlayout.widget.DrawerLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/drawer_layout"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 6
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 6
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 7
#       child_ids: 8
#       child_ids: 9
#       child_ids: 10
#       depth: 6
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 7
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/bottom_sheet_frame"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 6
#     }
#     nodes {
#       unique_id: 8
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 11
#       child_ids: 12
#       child_ids: 13
#       depth: 7
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 9
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/coordinator_layout"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 14
#       child_ids: 15
#       child_ids: 16
#       child_ids: 17
#       child_ids: 18
#       depth: 7
#       drawing_order: 5
#     }
#     nodes {
#       unique_id: 10
#       bounds_in_screen {
#         top: 2337
#         right: 1080
#         bottom: 2337
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/hats_next_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 7
#     }
#     nodes {
#       unique_id: 11
#       bounds_in_screen {
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/header"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 19
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 12
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/banner_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 13
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/main_pane"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 20
#       depth: 8
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 14
#       bounds_in_screen {
#         left: 891
#         top: 2148
#         right: 1038
#         bottom: 2295
#       }
#       class_name: "android.widget.ImageButton"
#       content_description: "Create new event or other calendar entries"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/floating_action_button"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 15
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 16
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 17
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 18
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 5
#     }
#     nodes {
#       unique_id: 19
#       bounds_in_screen {
#         top: 136
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/toolbar"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 21
#       child_ids: 22
#       child_ids: 23
#       child_ids: 24
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 20
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/alternate_timeline_holder"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 25
#       child_ids: 26
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 21
#       bounds_in_screen {
#         left: 11
#         top: 146
#         right: 158
#         bottom: 293
#       }
#       class_name: "android.widget.ImageButton"
#       content_description: "Show Calendar List and Settings drawer"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 10
#       drawing_order: 3
#       tooltip_text: "Show Calendar List and Settings drawer"
#     }
#     nodes {
#       unique_id: 22
#       bounds_in_screen {
#         left: 158
#         top: 219
#         right: 159
#         bottom: 220
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 23
#       bounds_in_screen {
#         left: 159
#         top: 146
#         right: 669
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/custom_action_bar"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 27
#       depth: 10
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 24
#       bounds_in_screen {
#         left: 679
#         top: 146
#         right: 1080
#         bottom: 293
#       }
#       class_name: "android.support.v7.widget.LinearLayoutCompat"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 28
#       child_ids: 29
#       child_ids: 30
#       depth: 10
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 25
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 31
#       child_ids: 32
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 26
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/alternate_timeline_fragment_container"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 33
#       depth: 10
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 27
#       bounds_in_screen {
#         left: 159
#         top: 146
#         right: 669
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       content_description: "July, Show date picker"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_button"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 34
#       depth: 11
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 28
#       bounds_in_screen {
#         left: 679
#         top: 156
#         right: 806
#         bottom: 282
#       }
#       class_name: "android.widget.Button"
#       content_description: "Search"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_search"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 11
#       drawing_order: 1
#       tooltip_text: "Search"
#     }
#     nodes {
#       unique_id: 29
#       bounds_in_screen {
#         left: 806
#         top: 156
#         right: 933
#         bottom: 282
#       }
#       class_name: "android.widget.Button"
#       content_description: "Jump to Today"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_today"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 11
#       drawing_order: 2
#       tooltip_text: "Jump to Today"
#     }
#     nodes {
#       unique_id: 30
#       bounds_in_screen {
#         left: 933
#         top: 156
#         right: 1080
#         bottom: 282
#       }
#       class_name: "android.widget.FrameLayout"
#       content_description: "Signed in as Cerebra Research dbwscratch.test.id3@gmail.com\nAccount and settings."
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/selected_account_disc"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 35
#       depth: 11
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 31
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/drag_up_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 32
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/timely_date_picker_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 33
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.support.v7.widget.RecyclerView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 36
#       child_ids: 37
#       child_ids: 38
#       child_ids: 39
#       child_ids: 41
#       child_ids: 43
#       child_ids: 45
#       child_ids: 46
#       child_ids: 47
#       child_ids: 48
#       child_ids: 49
#       child_ids: 50
#       child_ids: 51
#       child_ids: 52
#       child_ids: 53
#       child_ids: 54
#       child_ids: 55
#       child_ids: 56
#       child_ids: 57
#       child_ids: 58
#       child_ids: 59
#       child_ids: 60
#       child_ids: 61
#       child_ids: 62
#       child_ids: 63
#       child_ids: 64
#       child_ids: 65
#       child_ids: 66
#       child_ids: 67
#       child_ids: 68
#       child_ids: 69
#       child_ids: 70
#       depth: 11
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 34
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 40
#       depth: 12
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 35
#       bounds_in_screen {
#         left: 933
#         top: 156
#         right: 1059
#         bottom: 282
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/og_selected_account_disc_apd"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 42
#       child_ids: 44
#       depth: 12
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 36
#       bounds_in_screen {
#         top: 341
#         right: 168
#         bottom: 509
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 25 July 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 37
#       bounds_in_screen {
#         left: 168
#         top: 346
#         right: 1038
#         bottom: 483
#       }
#       class_name: "android.view.View"
#       content_description: "Below Benchmark, 3:30 PM – 4:30 PM, dbwscratch.test.id3@gmail.com"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 38
#       bounds_in_screen {
#         top: 346
#         right: 1080
#         bottom: 557
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 39
#       bounds_in_screen {
#         top: 552
#         right: 168
#         bottom: 720
#       }
#       class_name: "android.view.View"
#       content_description: "Saturday 29 July 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 41
#       bounds_in_screen {
#         left: 168
#         top: 557
#         right: 1038
#         bottom: 641
#       }
#       class_name: "android.view.View"
#       content_description: "Muharram/Ashura, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 43
#       bounds_in_screen {
#         top: 557
#         right: 1080
#         bottom: 725
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 45
#       bounds_in_screen {
#         left: 168
#         top: 725
#         right: 1080
#         bottom: 780
#       }
#       class_name: "android.view.View"
#       content_description: "Jul 30 – Aug 5"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 46
#       bounds_in_screen {
#         top: 725
#         right: 1080
#         bottom: 812
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
# ...
#         left: 168
#         top: 1317
#         right: 1080
#         bottom: 1372
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 6 – 12"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 50
#       bounds_in_screen {
#         top: 1317
#         right: 1080
#         bottom: 1404
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 51
#       bounds_in_screen {
#         left: 168
#         top: 1404
#         right: 1080
#         bottom: 1459
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 13 – 19"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 52
#       bounds_in_screen {
#         top: 1404
#         right: 1080
#         bottom: 1491
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 53
#       bounds_in_screen {
#         top: 1486
#         right: 168
#         bottom: 1654
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 15 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 54
#       bounds_in_screen {
#         left: 168
#         top: 1491
#         right: 1038
#         bottom: 1575
#       }
#       class_name: "android.view.View"
#       content_description: "Independence Day, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 55
#       bounds_in_screen {
#         top: 1491
#         right: 1080
#         bottom: 1659
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 56
#       bounds_in_screen {
#         top: 1654
#         right: 168
#         bottom: 1822
#       }
#       class_name: "android.view.View"
#       content_description: "Wednesday 16 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 57
#       bounds_in_screen {
#         left: 168
#         top: 1659
#         right: 1038
#         bottom: 1743
#       }
#       class_name: "android.view.View"
#       content_description: "Parsi New Year, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 58
#       bounds_in_screen {
#         top: 1659
#         right: 1080
#         bottom: 1827
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 59
#       bounds_in_screen {
#         left: 168
#         top: 1827
#         right: 1080
#         bottom: 1882
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 20 – 26"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 60
#       bounds_in_screen {
#         top: 1909
#         right: 168
#         bottom: 2077
#       }
#       class_name: "android.view.View"
#       content_description: "Sunday 20 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 61
#       bounds_in_screen {
#         left: 168
#         top: 1914
#         right: 1038
#         bottom: 1998
#       }
#       class_name: "android.view.View"
#       content_description: "Vinayaka Chathurthi, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 62
#       bounds_in_screen {
#         top: 1827
#         right: 1080
#         bottom: 2082
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 63
#       bounds_in_screen {
#         left: 168
#         top: 2082
#         right: 1080
#         bottom: 2137
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 27 – Sep 2"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 64
#       bounds_in_screen {
#         top: 2082
#         right: 1080
#         bottom: 2169
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 65
#       bounds_in_screen {
#         top: 2164
#         right: 168
#         bottom: 2332
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 29 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 66
#       bounds_in_screen {
#         left: 168
#         top: 2169
#         right: 1038
#         bottom: 2253
#       }
#       class_name: "android.view.View"
#       content_description: "Onam, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 67
#       bounds_in_screen {
#         top: 2169
#         right: 1080
#         bottom: 2337
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 68
#       bounds_in_screen {
#         top: 2332
#         right: 168
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       content_description: "Wednesday 30 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 69
#       bounds_in_screen {
#         left: 168
#         top: 2337
#         right: 1038
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       content_description: "Raksha Bandhan (Rakhi), All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 70
#       bounds_in_screen {
#         top: 2337
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_scrollable: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       actions {
#         id: 4096
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 40
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_content"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 71
#       depth: 13
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 42
#       bounds_in_screen {
#         left: 938
#         top: 161
#         right: 938
#         bottom: 161
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/ring_wrapper"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 13
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 44
#       bounds_in_screen {
#         left: 938
#         top: 161
#         right: 1054
#         bottom: 277
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/og_apd_internal_image_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 13
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 71
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 72
#       depth: 14
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 72
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 73
#       child_ids: 74
#       depth: 15
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 73
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 265
#         bottom: 293
#       }
#       class_name: "android.widget.TextView"
#       package_name: "com.google.android.calendar"
#       text: "July"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_text_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 16
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 74
#       bounds_in_screen {
#         left: 265
#         top: 193
#         right: 318
#         bottom: 246
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_arrow"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 16
#       drawing_order: 2
#     }
#   }
# }

# %%
from PIL import Image
import io

image = Image.open(io.BytesIO(screenshots[0]))
image.save("first_screenshot.png")

# %%
for i, raw_record in enumerate(dataset.take(1)):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())

    features = example.features.feature

    goal = features["goal"].bytes_list.value[0].decode("utf-8")
    screenshots = features["screenshots"].bytes_list.value

    print(f"🎯 Example #{i} Goal: {goal}")
    for j in range(len(screenshots)):
        image = Image.open(io.BytesIO(screenshots[j]))
        image.save(f"example_{i}_{j}_screenshot.png")
# Out:
# 🎯 Example #0 Goal: Open the Zoho Meet app , view the scheduled meetings .

# %%
with open("intermediate_data/sample_0.json","r") as f:
    data = json.load(f)

#print(data)

goal = data["goal"]
step_instruction = data["step_instruction"]
action = data["action"]
image_path = data["image_path"]
accessibility_bytes = example.features.feature["accessibility_trees"].bytes_list.value[0]



prompt = f"Goal: {goal}\nInstruction:{step_instruction}\nWhat action should be taken?"

image = Image.open(image_path).convert("RGB")


print(prompt)
#display(image)

print(action)
print("\n")

forest = android_accessibility_forest_pb2.AndroidAccessibilityForest().FromString(accessibility_bytes)
print(forest)
# Out:
# Goal: Open the Zoho Meet app , view the scheduled meetings .
# Instruction:Open the Zoho Meet app
# What action should be taken?
# {'action_type': 'open_app', 'app_name': 'Zoho Meeting'}
#
#
# windows {
#   bounds_in_screen {
#     right: 1080
#     bottom: 136
#   }
#   id: 5
#   layer: 1
#   window_type: TYPE_SYSTEM
#   tree {
#     nodes {
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 1
#       child_ids: 2
#       child_ids: 3
#     }
#     nodes {
#       unique_id: 1
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_launch_animation_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 1
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 2
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 1
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 3
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 4
#       depth: 1
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 4
#       bounds_in_screen {
#         right: 1080
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 5
#       depth: 2
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 5
#       bounds_in_screen {
#         left: 145
#         right: 1027
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_contents"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 6
#       child_ids: 7
#       depth: 3
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 6
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 575
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 8
#       depth: 4
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 7
#       bounds_in_screen {
#         left: 575
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_end_side_container"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 10
#       depth: 4
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 8
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_content"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 9
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 10
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_end_side_content"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 11
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 9
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/status_bar_start_side_except_heads_up"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 12
#       child_ids: 13
#       depth: 6
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 11
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/system_icons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 14
#       child_ids: 15
#       depth: 6
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 12
#       bounds_in_screen {
#         left: 145
#         top: 1
#         right: 229
#         bottom: 136
#       }
#       class_name: "android.widget.TextView"
#       content_description: "8:37 AM"
#       package_name: "com.android.systemui"
#       text: "8:37"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/clock"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 13
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/notification_icon_area"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 16
#       depth: 7
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 14
#       bounds_in_screen {
#         left: 924
#         top: 1
#         right: 986
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/statusIcons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 17
#       depth: 7
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 15
#       bounds_in_screen {
#         left: 986
#         top: 1
#         right: 1006
#         bottom: 136
#       }
#       class_name: "android.widget.LinearLayout"
#       content_description: "Battery charging, 100 percent."
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/battery"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 18
#       depth: 7
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 16
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/notificationIcons"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 19
#       child_ids: 20
#       child_ids: 21
#       child_ids: 22
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 17
#       bounds_in_screen {
#         left: 924
#         top: 39
#         right: 970
#         bottom: 97
#       }
#       class_name: "android.widget.FrameLayout"
#       content_description: "Wifi two bars."
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_combo"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 23
#       depth: 8
#       drawing_order: 14
#     }
#     nodes {
#       unique_id: 18
#       bounds_in_screen {
#         left: 986
#         top: 51
#         right: 1006
#         bottom: 85
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 19
#       bounds_in_screen {
#         left: 229
#         top: 1
#         right: 287
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Clock notification: Missed alarm"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 20
#       bounds_in_screen {
#         left: 287
#         top: 1
#         right: 345
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Gmail notification: 6 new messages"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 21
#       bounds_in_screen {
#         left: 345
#         top: 1
#         right: 403
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "System update notification: Android 13"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 22
#       bounds_in_screen {
#         left: 403
#         top: 1
#         right: 461
#         bottom: 136
#       }
#       class_name: "android.widget.ImageView"
#       content_description: "Google notification: Today in New Delhi: Scattered thunderstorms"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 9
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 23
#       bounds_in_screen {
#         left: 931
#         top: 39
#         right: 970
#         bottom: 97
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_group"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 24
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 24
#       bounds_in_screen {
#         left: 931
#         top: 48
#         right: 970
#         bottom: 87
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_combo"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 25
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 25
#       bounds_in_screen {
#         left: 931
#         top: 48
#         right: 970
#         bottom: 87
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.android.systemui"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.android.systemui:id/wifi_signal"
#       window_id: 5
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 1
#     }
#   }
# }
# windows {
#   bounds_in_screen {
#     right: 1080
#     bottom: 2400
#   }
#   id: 1729
#   title: "Calendar"
#   window_type: TYPE_APPLICATION
#   is_active: true
#   is_focused: true
#   tree {
#     nodes {
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 1
#     }
#     nodes {
#       unique_id: 1
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 2
#       depth: 1
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 2
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 3
#       depth: 2
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 3
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_bar_root"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 4
#       depth: 3
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 4
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "android:id/content"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 5
#       depth: 4
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 5
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "androidx.drawerlayout.widget.DrawerLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/drawer_layout"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 6
#       depth: 5
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 6
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 7
#       child_ids: 8
#       child_ids: 9
#       child_ids: 10
#       depth: 6
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 7
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/bottom_sheet_frame"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 6
#     }
#     nodes {
#       unique_id: 8
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 11
#       child_ids: 12
#       child_ids: 13
#       depth: 7
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 9
#       bounds_in_screen {
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/coordinator_layout"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 14
#       child_ids: 15
#       child_ids: 16
#       child_ids: 17
#       child_ids: 18
#       depth: 7
#       drawing_order: 5
#     }
#     nodes {
#       unique_id: 10
#       bounds_in_screen {
#         top: 2337
#         right: 1080
#         bottom: 2337
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/hats_next_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 7
#       drawing_order: 7
#     }
#     nodes {
#       unique_id: 11
#       bounds_in_screen {
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/header"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 19
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 12
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/banner_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 13
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/main_pane"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 20
#       depth: 8
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 14
#       bounds_in_screen {
#         left: 891
#         top: 2148
#         right: 1038
#         bottom: 2295
#       }
#       class_name: "android.widget.ImageButton"
#       content_description: "Create new event or other calendar entries"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/floating_action_button"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 15
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 16
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 17
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 18
#       bounds_in_screen {
#         top: 2400
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 8
#       drawing_order: 5
#     }
#     nodes {
#       unique_id: 19
#       bounds_in_screen {
#         top: 136
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.view.ViewGroup"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/toolbar"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 21
#       child_ids: 22
#       child_ids: 23
#       child_ids: 24
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 20
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/alternate_timeline_holder"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 25
#       child_ids: 26
#       depth: 9
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 21
#       bounds_in_screen {
#         left: 11
#         top: 146
#         right: 158
#         bottom: 293
#       }
#       class_name: "android.widget.ImageButton"
#       content_description: "Show Calendar List and Settings drawer"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 10
#       drawing_order: 3
#       tooltip_text: "Show Calendar List and Settings drawer"
#     }
#     nodes {
#       unique_id: 22
#       bounds_in_screen {
#         left: 158
#         top: 219
#         right: 159
#         bottom: 220
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 23
#       bounds_in_screen {
#         left: 159
#         top: 146
#         right: 669
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/custom_action_bar"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 27
#       depth: 10
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 24
#       bounds_in_screen {
#         left: 679
#         top: 146
#         right: 1080
#         bottom: 293
#       }
#       class_name: "android.support.v7.widget.LinearLayoutCompat"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 28
#       child_ids: 29
#       child_ids: 30
#       depth: 10
#       drawing_order: 4
#     }
#     nodes {
#       unique_id: 25
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 31
#       child_ids: 32
#       depth: 10
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 26
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/alternate_timeline_fragment_container"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 33
#       depth: 10
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 27
#       bounds_in_screen {
#         left: 159
#         top: 146
#         right: 669
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       content_description: "July, Show date picker"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_button"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 34
#       depth: 11
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 28
#       bounds_in_screen {
#         left: 679
#         top: 156
#         right: 806
#         bottom: 282
#       }
#       class_name: "android.widget.Button"
#       content_description: "Search"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_search"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 11
#       drawing_order: 1
#       tooltip_text: "Search"
#     }
#     nodes {
#       unique_id: 29
#       bounds_in_screen {
#         left: 806
#         top: 156
#         right: 933
#         bottom: 282
#       }
#       class_name: "android.widget.Button"
#       content_description: "Jump to Today"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/action_today"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       actions {
#         id: 16908356
#       }
#       depth: 11
#       drawing_order: 2
#       tooltip_text: "Jump to Today"
#     }
#     nodes {
#       unique_id: 30
#       bounds_in_screen {
#         left: 933
#         top: 156
#         right: 1080
#         bottom: 282
#       }
#       class_name: "android.widget.FrameLayout"
#       content_description: "Signed in as Cerebra Research dbwscratch.test.id3@gmail.com\nAccount and settings."
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/selected_account_disc"
#       window_id: 1729
#       is_clickable: true
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 16
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 35
#       depth: 11
#       drawing_order: 3
#     }
#     nodes {
#       unique_id: 31
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/drag_up_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 32
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 304
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/timely_date_picker_container"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 11
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 33
#       bounds_in_screen {
#         top: 304
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.support.v7.widget.RecyclerView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 36
#       child_ids: 37
#       child_ids: 38
#       child_ids: 39
#       child_ids: 41
#       child_ids: 43
#       child_ids: 45
#       child_ids: 46
#       child_ids: 47
#       child_ids: 48
#       child_ids: 49
#       child_ids: 50
#       child_ids: 51
#       child_ids: 52
#       child_ids: 53
#       child_ids: 54
#       child_ids: 55
#       child_ids: 56
#       child_ids: 57
#       child_ids: 58
#       child_ids: 59
#       child_ids: 60
#       child_ids: 61
#       child_ids: 62
#       child_ids: 63
#       child_ids: 64
#       child_ids: 65
#       child_ids: 66
#       child_ids: 67
#       child_ids: 68
#       child_ids: 69
#       child_ids: 70
#       depth: 11
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 34
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 40
#       depth: 12
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 35
#       bounds_in_screen {
#         left: 933
#         top: 156
#         right: 1059
#         bottom: 282
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/og_selected_account_disc_apd"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 42
#       child_ids: 44
#       depth: 12
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 36
#       bounds_in_screen {
#         top: 341
#         right: 168
#         bottom: 509
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 25 July 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 37
#       bounds_in_screen {
#         left: 168
#         top: 346
#         right: 1038
#         bottom: 483
#       }
#       class_name: "android.view.View"
#       content_description: "Below Benchmark, 3:30 PM – 4:30 PM, dbwscratch.test.id3@gmail.com"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 38
#       bounds_in_screen {
#         top: 346
#         right: 1080
#         bottom: 557
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 39
#       bounds_in_screen {
#         top: 552
#         right: 168
#         bottom: 720
#       }
#       class_name: "android.view.View"
#       content_description: "Saturday 29 July 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 41
#       bounds_in_screen {
#         left: 168
#         top: 557
#         right: 1038
#         bottom: 641
#       }
#       class_name: "android.view.View"
#       content_description: "Muharram/Ashura, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 43
#       bounds_in_screen {
#         top: 557
#         right: 1080
#         bottom: 725
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 45
#       bounds_in_screen {
#         left: 168
#         top: 725
#         right: 1080
#         bottom: 780
#       }
#       class_name: "android.view.View"
#       content_description: "Jul 30 – Aug 5"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 46
#       bounds_in_screen {
#         top: 725
#         right: 1080
#         bottom: 812
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 47
#       bounds_in_screen {
#         top: 812
#         right: 1080
#         bottom: 1285
#       }
#       class_name: "android.view.View"
#       content_description: "August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
# ...
#         left: 168
#         top: 1317
#         right: 1080
#         bottom: 1372
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 6 – 12"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 50
#       bounds_in_screen {
#         top: 1317
#         right: 1080
#         bottom: 1404
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 51
#       bounds_in_screen {
#         left: 168
#         top: 1404
#         right: 1080
#         bottom: 1459
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 13 – 19"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 52
#       bounds_in_screen {
#         top: 1404
#         right: 1080
#         bottom: 1491
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 53
#       bounds_in_screen {
#         top: 1486
#         right: 168
#         bottom: 1654
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 15 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 54
#       bounds_in_screen {
#         left: 168
#         top: 1491
#         right: 1038
#         bottom: 1575
#       }
#       class_name: "android.view.View"
#       content_description: "Independence Day, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 55
#       bounds_in_screen {
#         top: 1491
#         right: 1080
#         bottom: 1659
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 56
#       bounds_in_screen {
#         top: 1654
#         right: 168
#         bottom: 1822
#       }
#       class_name: "android.view.View"
#       content_description: "Wednesday 16 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 57
#       bounds_in_screen {
#         left: 168
#         top: 1659
#         right: 1038
#         bottom: 1743
#       }
#       class_name: "android.view.View"
#       content_description: "Parsi New Year, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 58
#       bounds_in_screen {
#         top: 1659
#         right: 1080
#         bottom: 1827
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 59
#       bounds_in_screen {
#         left: 168
#         top: 1827
#         right: 1080
#         bottom: 1882
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 20 – 26"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 60
#       bounds_in_screen {
#         top: 1909
#         right: 168
#         bottom: 2077
#       }
#       class_name: "android.view.View"
#       content_description: "Sunday 20 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 61
#       bounds_in_screen {
#         left: 168
#         top: 1914
#         right: 1038
#         bottom: 1998
#       }
#       class_name: "android.view.View"
#       content_description: "Vinayaka Chathurthi, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 62
#       bounds_in_screen {
#         top: 1827
#         right: 1080
#         bottom: 2082
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 63
#       bounds_in_screen {
#         left: 168
#         top: 2082
#         right: 1080
#         bottom: 2137
#       }
#       class_name: "android.view.View"
#       content_description: "Aug 27 – Sep 2"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 64
#       bounds_in_screen {
#         top: 2082
#         right: 1080
#         bottom: 2169
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 65
#       bounds_in_screen {
#         top: 2164
#         right: 168
#         bottom: 2332
#       }
#       class_name: "android.view.View"
#       content_description: "Tuesday 29 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 66
#       bounds_in_screen {
#         left: 168
#         top: 2169
#         right: 1038
#         bottom: 2253
#       }
#       class_name: "android.view.View"
#       content_description: "Onam, All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 67
#       bounds_in_screen {
#         top: 2169
#         right: 1080
#         bottom: 2337
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 68
#       bounds_in_screen {
#         top: 2332
#         right: 168
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       content_description: "Wednesday 30 August 2023"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 69
#       bounds_in_screen {
#         left: 168
#         top: 2337
#         right: 1038
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       content_description: "Raksha Bandhan (Rakhi), All day: , dbwscratch.test.id3@gmail.com, Holidays in India"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_focusable: true
#       is_visible_to_user: true
#       actions {
#         id: 1
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 70
#       bounds_in_screen {
#         top: 2337
#         right: 1080
#         bottom: 2400
#       }
#       class_name: "android.view.View"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_scrollable: true
#       is_visible_to_user: true
#       actions {
#         id: 64
#       }
#       actions {
#         id: 4096
#       }
#       depth: 12
#     }
#     nodes {
#       unique_id: 40
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_content"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 71
#       depth: 13
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 42
#       bounds_in_screen {
#         left: 938
#         top: 161
#         right: 938
#         bottom: 161
#       }
#       class_name: "android.widget.FrameLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/ring_wrapper"
#       window_id: 1729
#       is_enabled: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 13
#       drawing_order: 2
#     }
#     nodes {
#       unique_id: 44
#       bounds_in_screen {
#         left: 938
#         top: 161
#         right: 1054
#         bottom: 277
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/og_apd_internal_image_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 13
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 71
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 72
#       depth: 14
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 72
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 318
#         bottom: 293
#       }
#       class_name: "android.widget.LinearLayout"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       child_ids: 73
#       child_ids: 74
#       depth: 15
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 73
#       bounds_in_screen {
#         left: 169
#         top: 146
#         right: 265
#         bottom: 293
#       }
#       class_name: "android.widget.TextView"
#       package_name: "com.google.android.calendar"
#       text: "July"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_text_view"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 256
#       }
#       actions {
#         id: 512
#       }
#       actions {
#         id: 131072
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 16
#       drawing_order: 1
#     }
#     nodes {
#       unique_id: 74
#       bounds_in_screen {
#         left: 265
#         top: 193
#         right: 318
#         bottom: 246
#       }
#       class_name: "android.widget.ImageView"
#       package_name: "com.google.android.calendar"
#       text_selection_start: -1
#       text_selection_end: -1
#       view_id_resource_name: "com.google.android.calendar:id/date_picker_arrow"
#       window_id: 1729
#       is_enabled: true
#       is_visible_to_user: true
#       actions {
#         id: 4
#       }
#       actions {
#         id: 8
#       }
#       actions {
#         id: 64
#       }
#       actions {
#         id: 16908342
#       }
#       depth: 16
#       drawing_order: 2
#     }
#   }
# }

# %%
raw_dataset = tf.data.TFRecordDataset("./dataset/android_control/android_control-00000-of-00020",compression_type="GZIP")
dataset_iterator = tf.compat.v1.data.make_one_shot_iterator(raw_dataset)

example = tf.train.Example.FromString(dataset_iterator.get_next().numpy())
features = example.features.feature

screenshots = features["screenshots"].bytes_list.value
forest = android_accessibility_forest_pb2.AndroidAccessibilityForest().FromString(features['accessibility_trees'].bytes_list.value[0])

# 读取 screenshots 和对应的 accessibility trees
screenshots = features["screenshots"].bytes_list.value
trees_raw = features["accessibility_trees"].bytes_list.value

# 检查它们的长度是否一致
print("Number of screenshots:", len(screenshots))
print("Number of accessibility trees:", len(trees_raw))
# Out:
# Number of screenshots: 4
# Number of accessibility trees: 4

# %%
from PIL import Image, ImageDraw, ImageFont
import io
import matplotlib.pyplot as plt

# %%
raw_dataset = tf.data.TFRecordDataset("./dataset/android_control/android_control-00015-of-00020",compression_type="GZIP")
dataset_iterator = tf.compat.v1.data.make_one_shot_iterator(raw_dataset)

example = tf.train.Example.FromString(dataset_iterator.get_next().numpy())
features = example.features.feature

screenshots = features["screenshots"].bytes_list.value
forest = android_accessibility_forest_pb2.AndroidAccessibilityForest().FromString(features['accessibility_trees'].bytes_list.value[0])

# 1. 载入 screenshot 图片
image = Image.open(io.BytesIO(screenshots[0])).convert("RGB")

# 2. 绘图准备
draw = ImageDraw.Draw(image)

# 3. 遍历 accessibility tree，画每一个 node 的 bbox
for idx, node in enumerate(forest.windows[1].tree.nodes):  # 默认选择 active window
    b = node.bounds_in_screen
    # 如果 bound 是合法的，绘制矩形和编号
    if b.left < b.right and b.top < b.bottom:
        draw.rectangle([(b.left, b.top), (b.right, b.bottom)], outline="red", width=2)
        draw.text((b.left + 2, b.top + 2), str(idx), fill="yellow")

# 4. 显示图像
plt.figure(figsize=(10, 20))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
import io

# 字体加载（如果有的话）
try:
    font_path = "/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf"
    font = ImageFont.truetype(font_path, 20)
except IOError:
    font = None

# 判断是否为可交互控件
def is_interactive(node):
    if hasattr(node, "is_clickable") and node.is_clickable:
        return True
    if any(a.id in [1, 16] for a in node.actions):  # click or long_click
        return True
    return False

# 获取截图和树
screenshots = features["screenshots"].bytes_list.value
trees_raw = features["accessibility_trees"].bytes_list.value
trees = [android_accessibility_forest_pb2.AndroidAccessibilityForest().FromString(t) for t in trees_raw]

# 遍历每一帧 observation
for i, (screenshot_bytes, forest) in enumerate(zip(screenshots, trees)):
    image = Image.open(io.BytesIO(screenshot_bytes)).convert("RGB")
    draw = ImageDraw.Draw(image)

    # 选中当前激活窗口
    active_window = next((w for w in forest.windows if w.is_active), forest.windows[-1])

    count = 0
    for node in active_window.tree.nodes:
        b = node.bounds_in_screen
        if b.left < b.right and b.top < b.bottom and is_interactive(node):
            # 绘制红色边框
            draw.rectangle([(b.left, b.top), (b.right, b.bottom)], outline="red", width=2)

            # 计算文字尺寸并绘制灰色半透明背景
            label = str(count)
            if font:
                text_size = draw.textbbox((0, 0), label, font=font)
            else:
                text_size = draw.textbbox((0, 0), label)
            text_width = text_size[2] - text_size[0]
            text_height = text_size[3] - text_size[1]

            # 创建灰色半透明背景
            bg_rect = [(b.left, b.top), (b.left + text_width + 6, b.top + text_height + 4)]
            draw.rectangle(bg_rect, fill=(169, 169, 169, 128))  # 灰色半透明背景

            # 绘制白色文字
            draw.text((b.left + 3, b.top + 2), label, fill="white", font=font)
            count += 1

    # 显示
    plt.figure(figsize=(6, 12))
    plt.title(f"Screenshot {i}")
    plt.imshow(image)
    plt.axis("off")
    plt.show()
